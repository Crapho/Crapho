# %% [markdown]
# <a href="https://colab.research.google.com/github/Crapho/Crapho/blob/main/data_organising.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel ("/content/sample_data/Book1.xlsx", sheet_name= 0)
df2 = pd.read_excel ("/content/sample_data/Book1.xlsx", sheet_name= 1)

# %%
df1.head()
df1.tail()
# Out:
#                                                 scheme   N/T/S  \
# 170  Livestock Census and Integrated Sample Survey ...  Normal
# 171  Livestock Health and Diseases Control CASP (9979)  Normal
# 172                                                NaN    SCCS
# 173                                                NaN   Total
# 174                                              TOTAL     NaN
#
#     GOI realese_2019 GOI\nShare_2019 State\nShare_2019     Total_2019  \
# 170         19,13.10        20,52.29              ....       20,52.29
# 171         29,66.52        20,74.58              ....       20,74.58
# 172              NaN           10.16              ....          10.16
# 173              NaN        20,84.74              ....       20,84.74
# 174    4,23,94,67.71   1,41,13,38.41       45,53,35.12  1,86,66,73.53
#
#     GOI realese_2018 GOI\nShare_2018 State\nShare_2018     Total_2018
# 170          3,41.25         2,50.80              ....        2,50.80
# ...

# %%
df2
# Out:
#                                                 scheme            N/T/S  \
# 0                             National Bamboo\nMission           Normal
# 1                                                  NaN           Tribal
# 2                                                  NaN  Scheduled Caste
# 3    Integrated\nManagement of\nPublic Distribution...           Normal
# 4                                                  NaN           Normal
# ..                                                 ...              ...
# 167                                                NaN  Scheduled Caste
# 168                                       Swadhar Greh           Normal
# 169  Integrated Development and Management of Fishe...           Normal
# 170                                                NaN           Tribal
# 171                                                NaN  Scheduled Caste
#
#     GOI realese_2019 GOI\nShare_2019 State\nShare_2019 Total_2019  \
# ...

# %%
df2.head()
# Out:
#                                               scheme            N/T/S  \
# 0                           National Bamboo\nMission           Normal
# 1                                                NaN           Tribal
# 2                                                NaN  Scheduled Caste
# 3  Integrated\nManagement of\nPublic Distribution...           Normal
# 4                                                NaN           Normal
#
#   GOI realese_2019 GOI\nShare_2019 State\nShare_2019 Total_2019  \
# 0             1093              --                --     606.08
# 1              NaN              --                --     337.08
# 2              NaN              --                --     364.58
# 3           171.84              --               NaN         --
# 4              NaN              --                --     325.17
#
#   GOI realese_2018 GOI\nShare_2018 State\nShare_2018 Total_2018
# 0               --              --                --         --
# ...

# %%
df1
# Out:
#                                                 scheme   N/T/S  \
# 0    Intensification of Forest Management/Forest Fi...  Normal
# 1                              Project Elephant (0260)  Normal
# 2                 National Urban Health Mission (0416)  Normal
# 3                                                  NaN    SCCS
# 4                                                  NaN     TCS
# ..                                                 ...     ...
# 170  Livestock Census and Integrated Sample Survey ...  Normal
# 171  Livestock Health and Diseases Control CASP (9979)  Normal
# 172                                                NaN    SCCS
# 173                                                NaN   Total
# 174                                              TOTAL     NaN
#
#     GOI realese_2019 GOI\nShare_2019 State\nShare_2019     Total_2019  \
# 0            4,28.07            ....              ....           ....
# ...

# %%
#dataframe with a new column included
df.assign(Group='A')
#realigning columns
df.assign(Group='A')[['Group'] + df.columns.tolist()]
#diff method of adding column
df1.insert(0, 'stateC_code', '1')

# %%
#dropping a column
df1=df1.drop(columns=df1.iloc[:,[2,3,4]])

# %%
df1
# Out:
#                                                 scheme    Type     Total_2019  \
# 0    Intensification of Forest Management/Forest Fi...  Normal           ....
# 1                              Project Elephant (0260)  Normal           ....
# 2                 National Urban Health Mission (0416)  Normal          33.34
# 3                 National Urban Health Mission (0416)    SCCS       93,44.76
# 4                 National Urban Health Mission (0416)     TCS        5,29.14
# ..                                                 ...     ...            ...
# 170  Livestock Census and Integrated Sample Survey ...  Normal       20,52.29
# 171  Livestock Health and Diseases Control CASP (9979)  Normal       20,74.58
# 172  Livestock Health and Diseases Control CASP (9979)    SCCS          10.16
# 173  Livestock Health and Diseases Control CASP (9979)   Total       20,84.74
# 174                                              TOTAL     NaN  1,86,66,73.53
#
#         Total_2018  Types_Cat
# ...

# %%
df1=df1.drop(columns=df1.iloc[:,[3,4,5]])

# %%
#fill missing programme name in rows

# %%
df1
df1['scheme'].fillna(method='pad', inplace=True)

# %%
df1
# Out:
#                                                 scheme    Type  \
# 0    Intensification of Forest Management/Forest Fi...  Normal
# 1                              Project Elephant (0260)  Normal
# 2                 National Urban Health Mission (0416)  Normal
# 3                 National Urban Health Mission (0416)    SCCS
# 4                 National Urban Health Mission (0416)     TCS
# ..                                                 ...     ...
# 170  Livestock Census and Integrated Sample Survey ...  Normal
# 171  Livestock Health and Diseases Control CASP (9979)  Normal
# 172  Livestock Health and Diseases Control CASP (9979)    SCCS
# 173  Livestock Health and Diseases Control CASP (9979)   Total
# 174                                              TOTAL     NaN
#
#     GOI realese_2019 GOI\nShare_2019 State\nShare_2019     Total_2019  \
# 0            4,28.07            ....              ....           ....
# ...

# %%
df['Type'] = df['Type'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#rename column 
df1.rename(columns = {'N/T/S':'Type'}, inplace = True)

# %%
df1
# Out:
#                                                 scheme    Type     Total_2019  \
# 0    Intensification of Forest Management/Forest Fi...  Normal           ....
# 1                              Project Elephant (0260)  Normal           ....
# 2                 National Urban Health Mission (0416)  Normal          33.34
# 3                 National Urban Health Mission (0416)    SCCS       93,44.76
# 4                 National Urban Health Mission (0416)     TCS        5,29.14
# ..                                                 ...     ...            ...
# 170  Livestock Census and Integrated Sample Survey ...  Normal       20,52.29
# 171  Livestock Health and Diseases Control CASP (9979)  Normal       20,74.58
# 172  Livestock Health and Diseases Control CASP (9979)    SCCS          10.16
# 173  Livestock Health and Diseases Control CASP (9979)   Total       20,84.74
# 174                                              TOTAL     NaN  1,86,66,73.53
#
#         Total_2018
# ...

# %%
print (df1.dtypes)
# Out:
# scheme               object
# N/T/S                object
# GOI realese_2019     object
# GOI\nShare_2019      object
# State\nShare_2019    object
# Total_2019           object
# GOI realese_2018     object
# GOI\nShare_2018      object
# State\nShare_2018    object
# Total_2018           object
# dtype: object

# %%
# changing from string to float
df1['Type'] = df1['Type'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-97f947822ed6> in <module>()
# ----> 1 df1['Type'] = df1['Type'].astype(float)
#       2
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df1
# Out:
#                                                 scheme    Type     Total_2019  \
# 0    Intensification of Forest Management/Forest Fi...  Normal           ....
# 1                              Project Elephant (0260)  Normal           ....
# 2                 National Urban Health Mission (0416)  Normal          33.34
# 3                 National Urban Health Mission (0416)    SCCS       93,44.76
# 4                 National Urban Health Mission (0416)     TCS        5,29.14
# ..                                                 ...     ...            ...
# 170  Livestock Census and Integrated Sample Survey ...  Normal       20,52.29
# 171  Livestock Health and Diseases Control CASP (9979)  Normal       20,74.58
# 172  Livestock Health and Diseases Control CASP (9979)    SCCS          10.16
# 173  Livestock Health and Diseases Control CASP (9979)   Total       20,84.74
# 174                                              TOTAL     NaN  1,86,66,73.53
#
#         Total_2018
# ...

# %%
#chnaging from string to numeric
df1 ['Total_2019'] = pd.to_numeric(df1['Total_2019'])
df1 ['Total_2018'] = pd.to_numeric(df1['Total_2018'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "...."
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-038ed19bd3d6> in <module>()
#       1 #chnaging from string to numeric
# ----> 2 df1 ['Total_2019'] = pd.to_numeric(df1['Total_2019'])
#       3 df1 ['Total_2018'] = pd.to_numeric(df1['Total_2018'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     182         try:
#     183             values, _ = lib.maybe_convert_numeric(
# --> 184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
# ...

# %%
# convert all columns of DataFrame
df = df.apply(pd.to_numeric) # convert all columns of DataFrame

# convert just columns "a" and "b"
df[["a", "b"]] = df[["a", "b"]].apply(pd.to_numeric)

# convert Series
my_series = pd.to_numeric(my_series)

# convert column "a" of a DataFrame
df["a"] = pd.to_numeric(df["a"])

# %%
df1
# Out:
#                                                 scheme   N/T/S  \
# 0    Intensification of Forest Management/Forest Fi...  Normal
# 1                              Project Elephant (0260)  Normal
# 2                 National Urban Health Mission (0416)  Normal
# 3                                                  NaN    SCCS
# 4                                                  NaN     TCS
# ..                                                 ...     ...
# 170  Livestock Census and Integrated Sample Survey ...  Normal
# 171  Livestock Health and Diseases Control CASP (9979)  Normal
# 172                                                NaN    SCCS
# 173                                                NaN   Total
# 174                                              TOTAL     NaN
#
#     GOI realese_2019 GOI\nShare_2019 State\nShare_2019     Total_2019  \
# 0            4,28.07            ....              ....           ....
# ...

# %%
# creating a categorical column
df1['Type'] = df1['Type'].astype('category')
df1['Types_Cat'] = df1['Type'].cat.codes

# %%
df1
# Out:
#                                                 scheme    Type     Total_2019  \
# 0    Intensification of Forest Management/Forest Fi...  Normal           ....
# 1                              Project Elephant (0260)  Normal           ....
# 2                 National Urban Health Mission (0416)  Normal          33.34
# 3                 National Urban Health Mission (0416)    SCCS       93,44.76
# 4                 National Urban Health Mission (0416)     TCS        5,29.14
# ..                                                 ...     ...            ...
# 170  Livestock Census and Integrated Sample Survey ...  Normal       20,52.29
# 171  Livestock Health and Diseases Control CASP (9979)  Normal       20,74.58
# 172  Livestock Health and Diseases Control CASP (9979)    SCCS          10.16
# 173  Livestock Health and Diseases Control CASP (9979)   Total       20,84.74
# 174                                              TOTAL     NaN  1,86,66,73.53
#
#         Total_2018  Types_Cat
# ...

# %%
file_name = 'df1.xlsx'

# %%
df1['Normal'] = df1.where(df1['Types_Cat'] == '0', '', '0')

# %%
df1.to_excel('foo_1.xls')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   """Entry point for launching an IPython kernel.
